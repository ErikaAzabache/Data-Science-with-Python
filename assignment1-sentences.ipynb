# %% [markdown]
# ## Part 1: For each website, create a JSON object of the page that have

# %%
import requests
from html.parser import HTMLParser
import re
import csv
import os
import os.path
import pprint
import json

# Search a topic based on keywords
# Save all urls in a list
# From the content of the urls from that list, grab images, sentence contained, outgoing links, last modified
# Topic: felines

def request_page(url):
    '''makes a get request. Returns request object'''
    try:
        r = requests.get(url, allow_redirects=True)
        return r
    except:
        return 'exception'

def get_sentences(request_result, keywords):
    '''Gets sentences (string of letters that end in a period) that use keywords from a given url requested
    Input: r object
    Output: set of strings (of sentences). String 'exception' if there is an exception'''

    r = request_result

    if r != 'exception':
        sentences = re.findall(" [a-zA-Z ]+\.", str(r.content))
        topic_sentences = [sent for sent in sentences if any(keyword in sent for keyword in keywords)]
        return set(topic_sentences)
    else:
        return 'exception'

def get_last_modified(request_result):
    '''Returns last modified if available, otherwise it returns an empty string'''
    
    r = request_result

    if r != 'exception':
        header = requests.head(url).headers

        if 'Last-Modified' in header:
            return header['Last-Modified']
        else:
            return ''
    else:
        return 'exception'

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        '''writes all images in a file and outgoing links in another file'''
        if tag.lower() == 'img' and 'src' in (k.lower() for k, v in attrs):
            with open('images.csv', 'a') as img_file:
                img_file.write(dict(attrs).get('src') + ',')

        if tag.lower() == 'a' and 'href' in (k.lower() for k, v in attrs):
            with open('outgoing_links.csv', 'a') as links_file:
                links_file.write(dict(attrs).get('href') + ',')
                
def file_to_list(afile):
    '''Returns a list out of a csv file and deletes the file'''
    with open(afile) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=',')
            alist = set(list(csv_reader)[0])
    os.remove(afile)
    return alist

def get_images(request_result):
    '''Gets all images from a request object. 
    Input: r object
    Output: list strings (of image urls)'''

    r = request_result

    if r != 'exception':
        parser = MyHTMLParser()
        parser.feed(str(r.content))

        if os.path.isfile('images.csv'):
            images = list(file_to_list('images.csv'))
        else:
            images = []
        return images
    else:
        return 'exception'

def count_outlinks(request_result):
    '''Gets all images from a given url request result. 
    Input: r object
    Output: integet (count of image urls)'''

    r = request_result

    if r != 'exception':
        parser = MyHTMLParser()
        parser.feed(str(r.content))

        if os.path.isfile('outgoing_links.csv'):
            out_links = file_to_list('outgoing_links.csv')
        else:
            out_links = []

        return len(out_links)
    else:
        return 'exception'

# %%
keywords = ['cat', 'tiger', 'lion']
N_SENTENCES = 3
N_IMAGES = 3
topic_urls = []

for keyword in keywords:
    url = 'https://www.google.com/search?q='+ keyword
    r = requests.get(url, allow_redirects=True)
    keyword_urls = re.findall("https://[^<]+", str(r.content))
    topic_urls.extend(keyword_urls)

# topic_pages = [(url1, {'images':  [img1, img2, img3], 
#                   'sentences': [sentence1, sentence2, sentence3], 
#                   'n_outlinks': n, 
#                   'last_modified': date})
#             (url2, {}),
#             (url3, {})...]

topic_pages = []

for url in topic_urls:
    url_dict = {}
    if 'google' not in url and 'gstatic' not in url and 'youtube' not in url:
        r = request_page(url)
        if r != 'exception' and len(get_sentences(r, keywords)) != 0:
            url_dict['sentences'] = list(get_sentences(r, keywords))[:N_SENTENCES]
            img = get_images(r)[:N_IMAGES]
            img.extend((N_IMAGES - len(img))*['']) # to make sure all have the same number of images.
            url_dict['images'] = img
            url_dict['n_outlinks'] = count_outlinks(r)
            url_dict['last_modified'] = get_last_modified(r)
            url_tup = tuple((url, url_dict))
            topic_pages.append(url_tup)

json.dump(topic_pages, open('topic_pages.json', 'w'), indent=4)
pprint.pprint(topic_pages)
# Out:
# [('https://www.cat.com/&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQFggUMAA&amp;usg=AOvVaw1zB9zKWUPdce9NjLrngZ-E">',
#   {'images': ['',
#               'https://www.awf.org/sites/default/files/styles/featured_animals/public/media/gallery/wildlife/Lion/Lion_Billy_Dodson.jpg?itok=Q9a6icy1',
#               'https://www.awf.org/sites/default/files/styles/featured_animals/public/media/masthead/new_gorilla_masthead.jpg?itok=rTCQj1tC'],
#    'last_modified': '',
#    'n_outlinks': 189,
#    'sentences': [' Check out our extensive online parts catalog.']}),
#  ('https://www.cat.com/%252Bcat%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQIAgXMAA&amp;usg=AOvVaw3RFbqPYSlgAiP1miZnLkjq">Cached',
#   {'images': ['',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$'],
#    'last_modified': '',
#    'n_outlinks': 189,
#    'sentences': [' Check out our extensive online parts catalog.']}),
#  ('https://www.cat.com/en_ZA.html&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIGSgAMAA&amp;usg=AOvVaw1doAXqmXBFcYtmqwjK8mFD">English',
#   {'images': ['',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$'],
#    'last_modified': '',
#    'n_outlinks': 189,
#    'sentences': [' Check out our extensive online parts catalog.']}),
#  ('https://www.cat.com/fr_DZ.html&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIGigBMAA&amp;usg=AOvVaw3DxyG48AOpL8MmdZ66GmK7">Fran\\xe7ais',
#   {'images': ['',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$'],
#    'last_modified': '',
#    'n_outlinks': 189,
#    'sentences': [' Check out our extensive online parts catalog.']}),
#  ('https://www.cat.com/tr_TR.html&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIGygCMAA&amp;usg=AOvVaw3FjKBgCmRIsQ-Fu6tJtV7M">Turkish',
#   {'images': ['',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$'],
#    'last_modified': '',
#    'n_outlinks': 189,
#    'sentences': [' Check out our extensive online parts catalog.']}),
#  ('https://www.humanesociety.org/animals/cats&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQwW4IIzAD&amp;usg=AOvVaw3-GGMCt99N4aluyftT5Bm6">',
#   {'images': ['',
#               'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$',
#               '/sites/default/files/styles/360x245/public/2018/04/pig-265325_0.jpg?h=c4c70bbe&itok=mc1VD3Iu'],
#    'last_modified': 'Tue, 26 Mar 2019 04:19:02 GMT',
#    'n_outlinks': 41,
#    'sentences': [' location.']}),
#  ('https://en.wikipedia.org/wiki/',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               '/sites/default/files/styles/360x245/public/2018/04/pig-265325_0.jpg?h=c4c70bbe&itok=mc1VD3Iu'],
#    'last_modified': 'Tue, 26 Mar 2019 04:06:06 GMT',
#    'n_outlinks': 261,
#    'sentences': [' communication in languages other than English.',
#                  ' The Bond novel received broadly positive reviews at the '
#                  'time of publication.']}),
#  ('https://en.wikipedia.org/wiki/Cat%23Characteristics&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIILygAMAY&amp;usg=AOvVaw07Xh3N0wNldxsXURXNcs_E">Characteristics',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg'],
#    'last_modified': 'Tue, 26 Mar 2019 04:19:09 GMT',
#    'n_outlinks': 2814,
#    'sentences': [' later identified as a domestic cat.',
#                  ' but this enzyme has very little activity in cats.',
#                  ' and flattened ears indicates hostility.']}),
#  ('https://en.wikipedia.org/wiki/Cat%23Senses&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIMCgBMAY&amp;usg=AOvVaw1-a0K2eDv3KNW2uUfDJ3h3">Senses',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg'],
#    'last_modified': 'Tue, 26 Mar 2019 04:19:13 GMT',
#    'n_outlinks': 2814,
#    'sentences': [' later identified as a domestic cat.',
#                  ' but this enzyme has very little activity in cats.',
#                  ' and flattened ears indicates hostility.']}),
#  ('https://en.wikipedia.org/wiki/Cat%23Nutrition&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIMSgCMAY&amp;usg=AOvVaw1yh6SOwaWB4Z3kPzOv2H7J">Nutrition',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg'],
#    'last_modified': 'Tue, 26 Mar 2019 04:19:16 GMT',
#    'n_outlinks': 2814,
#    'sentences': [' later identified as a domestic cat.',
#                  ' but this enzyme has very little activity in cats.',
#                  ' and flattened ears indicates hostility.']}),
#  ('https://en.wikipedia.org/wiki/Cat%23Behavior&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQ0gIIMigDMAY&amp;usg=AOvVaw3fZuVNbWGp6yAgOSJTqyaT">Behavior',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg'],
#    'last_modified': 'Tue, 26 Mar 2019 04:19:19 GMT',
#    'n_outlinks': 2814,
#    'sentences': [' later identified as a domestic cat.',
#                  ' but this enzyme has very little activity in cats.',
#                  ' and flattened ears indicates hostility.']}),
#  ('https://www.webmd.com/pets/cats/default.htm&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQFgg6MAg&amp;usg=AOvVaw2iUBf5I7-MBs5ZWwG2htsE">',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg'],
#    'last_modified': '',
#    'n_outlinks': 0,
#    'sentences': [' application error occurred on the server.',
#                  ' Application.',
#                  ' configuration file located in the root directory of the '
#                  'current web application.']}),
#  ('https://www.webmd.com/pets/',
#   {'images': ['',
#               'https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/news/2015/06_2015/fake_online_pharmacies/110x70_fake_online_pharmacies.jpg?resize=110px:*&output-quality=50',
#               'https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/video/caring_for_dog_with_food_allergies_video/650x350_caring_for_dog_with_food_allergies_video.jpg?resize=195px:*&output-quality=50'],
#    'last_modified': '',
#    'n_outlinks': 220,
#    'sentences': [' you might not know about dogs and cats.']}),
#  ('https://www.petco.com/shop/en/petcostore/category/cat&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQFghEMAo&amp;usg=AOvVaw26EQxON8U1E0Q6VMM3cpuU">',
#   {'images': ['',
#               '/wcsstore/PetcoSAS/images/loading.gif',
#               '/wcsstore/PetcoStore/img/brand-logo.png'],
#    'last_modified': '',
#    'n_outlinks': 270,
#    'sentences': [' charges applicable tax on all orders to states in which '
#                  'Petco has a physical location.',
#                  ' cat toy order subtotal.',
#                  ' petcoLocation.']}),
#  ('https://www.petco.com/shop/en/petcostore/',
#   {'images': ['',
#               '/wcsstore/PetcoSAS/images/loading.gif',
#               '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120'],
#    'last_modified': '',
#    'n_outlinks': 283,
#    'sentences': [' charges applicable tax on all orders to states in which '
#                  'Petco has a physical location.',
#                  ' cat toy order subtotal.',
#                  ' petcoLocation.']}),
#  ('https://www.petco.com/shop/en/petcostore/category/cat%252Bcat%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQIAhHMAo&amp;usg=AOvVaw3RMccGUeLuapbmdahRENzT">Cached',
#   {'images': ['',
#               '/wcsstore/PetcoSAS/images/loading.gif',
#               '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120'],
#    'last_modified': '',
#    'n_outlinks': 270,
#    'sentences': [' charges applicable tax on all orders to states in which '
#                  'Petco has a physical location.',
#                  ' cat toy order subtotal.',
#                  ' petcoLocation.']}),
#  ('https://www.thesprucepets.com/cats-4162124&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQFghJMAs&amp;usg=AOvVaw0nvbuepqVzAN05yGc1EIOe">How '
#   'to Be a Responsible ',
#   {'images': ['',
#               '//s7d1.scene7.com/is/image/PETCO/rd-always-earn5back-051718-icon-36w-36h?$transparent_unsized$',
#               'https://s7d1.scene7.com/is/image/PETCO/bird-shop-by-pet-091117-thumbnail-175w-200h'],
#    'last_modified': '',
#    'n_outlinks': 5,
#    'sentences': [' location.']}),
#  ('https://www.thesprucepets.com/',
#   {'images': ['', '', ''],
#    'last_modified': '',
#    'n_outlinks': 37,
#    'sentences': [' location.']}),
#  ('https://www.thesprucepets.com/cats-4162124%252Bcat%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQIAhMMAs&amp;usg=AOvVaw2hvSA-zkHUwtCvIFkjIsy_">Cached',
#   {'images': ['', '', ''],
#    'last_modified': '',
#    'n_outlinks': 5,
#    'sentences': [' location.']}),
#  ('https://finance.yahoo.com/quote/CAT/&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQFghOMAw&amp;usg=AOvVaw2SD2t73jwHJ9gZOm5jxNhT">Caterpillar, '
#   'Inc. (',
#   {'images': ['',
#               'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a',
#               'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d'],
#    'last_modified': '',
#    'n_outlinks': 50,
#    'sentences': [' the Morningstar category is assigned based on the '
#                  'underlying securities in each portfolio.',
#                  ' billion.',
#                  ' million last year.']}),
#  ('https://finance.yahoo.com/quote/',
#   {'images': ['',
#               'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a',
#               'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d'],
#    'last_modified': '',
#    'n_outlinks': 29,
#    'sentences': [' the Morningstar category is assigned based on the '
#                  'underlying securities in each portfolio.',
#                  ' have no new notifications.',
#                  ' will send you notifications about latest breaking news.']}),
#  ('https://finance.yahoo.com/quote/CAT/%252Bcat%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwiXuZDz-Z7hAhXWvp4KHbYMBMwQIAhRMAw&amp;usg=AOvVaw1tF7yFEkDbtWTOubPvwosd">Cached',
#   {'images': ['',
#               'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a',
#               'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d'],
#    'last_modified': '',
#    'n_outlinks': 50,
#    'sentences': [' the Morningstar category is assigned based on the '
#                  'underlying securities in each portfolio.',
#                  ' billion.',
#                  ' million last year.']}),
#  ('https://en.wikipedia.org/wiki/',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d'],
#    'last_modified': 'Tue, 26 Mar 2019 04:06:06 GMT',
#    'n_outlinks': 261,
#    'sentences': [' communication in languages other than English.',
#                  ' The Bond novel received broadly positive reviews at the '
#                  'time of publication.']}),
#  ('https://nationalzoo.si.edu/animals/tiger&amp;sa=U&amp;ved=0ahUKEwisqLXz-Z7hAhVPnZ4KHb58A3QQFgg-MAk&amp;usg=AOvVaw0sMkErRgMME_VrSnnY1hiB">',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:09 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']}),
#  ('https://nationalzoo.si.edu/animals/',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679'],
#    'last_modified': '',
#    'n_outlinks': 97,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.']}),
#  ('https://nationalzoo.si.edu/animals/tiger%252Btiger%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwisqLXz-Z7hAhVPnZ4KHb58A3QQIAhBMAk&amp;usg=AOvVaw2UzjjJMxCahssS7oHAd8rP">Cached',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:15 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']}),
#  ('https://nationalzoo.si.edu/animals/lion&amp;sa=U&amp;ved=0ahUKEwiD1_bz-Z7hAhXSl54KHbSNDW0QwW4IHDAD&amp;usg=AOvVaw3jayPJpOv3_eXzld5P9ZFU">',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:24 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']}),
#  ('https://en.wikipedia.org/wiki/',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png'],
#    'last_modified': 'Tue, 26 Mar 2019 04:06:06 GMT',
#    'n_outlinks': 261,
#    'sentences': [' communication in languages other than English.',
#                  ' The Bond novel received broadly positive reviews at the '
#                  'time of publication.']}),
#  ('https://www.imdb.com/title/tt3741834/',
#   {'images': ['',
#               '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png',
#               'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/film-293970583._CB483525279_.png'],
#    'last_modified': '',
#    'n_outlinks': 377,
#    'sentences': [' a fearsome Bengal tiger.']}),
#  ('https://nationalzoo.si.edu/animals/lion&amp;sa=U&amp;ved=0ahUKEwiD1_bz-Z7hAhXSl54KHbSNDW0QFgg0MAc&amp;usg=AOvVaw2Osem34xUwFy8YIrPDlvc-">',
#   {'images': ['',
#               'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/film-293970583._CB483525279_.png',
#               'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/32x44/name-2138558783._CB470041625_.png'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:37 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']}),
#  ('https://nationalzoo.si.edu/animals/',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679'],
#    'last_modified': '',
#    'n_outlinks': 97,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.']}),
#  ('https://nationalzoo.si.edu/animals/lion%252Blion%26hl%3Den%26ct%3Dclnk&amp;sa=U&amp;ved=0ahUKEwiD1_bz-Z7hAhXSl54KHbSNDW0QIAg3MAc&amp;usg=AOvVaw0VxyrA5u6EqRv81mApq40p">Cached',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:45 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']}),
#  ('https://nationalzoo.si.edu/animals/lion+lion&amp;tbo=1&amp;sa=X&amp;ved=0ahUKEwiD1_bz-Z7hAhXSl54KHbSNDW0QHwg4MAc">Similar',
#   {'images': ['/sites/all/themes/si_nzp/logo.svg',
#               '',
#               'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-'],
#    'last_modified': 'Tue, 26 Mar 2019 04:21:52 GMT',
#    'n_outlinks': 91,
#    'sentences': [' We offer visitors a chat bot concierge that may not be '
#                  'compatible with your accessibility application.',
#                  ' million visitors from all over the world each year.']})]

# %% [markdown]
# ## Part 2: Flatten the output of part 1 by sentences and write to a CSV

# %%
def flatten_by_sentence(json_obj):
    '''Takes the json object created in part one:
        topic_pages = [
                    (url1, {'images':  ['https://aaa.com/a.jpg'], 
                          'sentences': [' lions roamed the Earth.', sentence12, sentence13], 
                          'n_outlinks': 5, 
                          'last_modified': 10:20:40 pm Apr 3 2019})
                    (url2, {'images': ['https://bbb.com/b.jpg', 'https://ccc.com/c.jpg'], 
                            'sentences': ['a fearsome Bengal tiger.', sentence22, sentence23]
                            'n_outlinks': 5, 
                            'last_modified': ''}),
                    (url3, {})...
                    ]
    and flattens it to be of the form:
    entence,                    image1,                 image2,                 image3, n outgoing links, last modified
    “ lions roamed the Earth.”, “https://aaa.com/a.jpg”, ?,                         ?,          5,          10:20:40 pm Apr 3 2019
    sentence12                , “https://aaa.com/a.jpg”, ?,                         ?,          5,          10:20:40 pm Apr 3 2019
    sentence13                , “https://aaa.com/a.jpg”, ?,                         ?,          5,          10:20:40 pm Apr 3 2019
    “ a fearsome Bengal tiger.”, “https://bbb.com/b.jpg”, “https://ccc.com/c.jpg”,  ?,          5,          ?
    sentence22                 , “https://bbb.com/b.jpg”, “https://ccc.com/c.jpg”,  ?,          5,          ?
    sentence23                 , “https://bbb.com/b.jpg”, “https://ccc.com/c.jpg”,  ?,          5,          ?
    '''

    with open(json_obj) as json_data:
        topic_data = json.load(json_data)

    for url_tup in topic_data:
        sentences = url_tup[1]['sentences']
        images = url_tup[1]['images']
        n_outlinks = url_tup[1]['n_outlinks']
        last_modified = url_tup[1]['last_modified']
        
        chunk = []
        for sentence in sentences:
            line = []
            line.append(sentence)
            line.extend(images)
            line.append(n_outlinks)
            line.append(last_modified)
            chunk.append(line)

        with open('topic_pages.csv', 'a') as csvfile:
            csvwriter = csv.writer(csvfile) 
            csvwriter.writerows(chunk)
            print(chunk)

flatten_by_sentence('topic_pages.json')
# Out:
# [[' Check out our extensive online parts catalog.', '', 'https://www.awf.org/sites/default/files/styles/featured_animals/public/media/gallery/wildlife/Lion/Lion_Billy_Dodson.jpg?itok=Q9a6icy1', 'https://www.awf.org/sites/default/files/styles/featured_animals/public/media/masthead/new_gorilla_masthead.jpg?itok=rTCQj1tC', 189, '']]
# [[' Check out our extensive online parts catalog.', '', 'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$', 'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$', 189, '']]
# [[' Check out our extensive online parts catalog.', '', 'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$', 'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$', 189, '']]
# [[' Check out our extensive online parts catalog.', '', 'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$', 'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$', 189, '']]
# [[' Check out our extensive online parts catalog.', '', 'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$', 'http://s7d2.scene7.com/is/image/Caterpillar/C755332?$cc-s$', 189, '']]
# [[' location.', '', 'http://s7d2.scene7.com/is/image/Caterpillar/C555056?$cc-s$', '/sites/default/files/styles/360x245/public/2018/04/pig-265325_0.jpg?h=c4c70bbe&itok=mc1VD3Iu', 41, 'Tue, 26 Mar 2019 04:19:02 GMT']]
# [[' communication in languages other than English.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '/sites/default/files/styles/360x245/public/2018/04/pig-265325_0.jpg?h=c4c70bbe&itok=mc1VD3Iu', 261, 'Tue, 26 Mar 2019 04:06:06 GMT'], [' The Bond novel received broadly positive reviews at the time of publication.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '/sites/default/files/styles/360x245/public/2018/04/pig-265325_0.jpg?h=c4c70bbe&itok=mc1VD3Iu', 261, 'Tue, 26 Mar 2019 04:06:06 GMT']]
# [[' later identified as a domestic cat.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', 2814, 'Tue, 26 Mar 2019 04:19:09 GMT'], [' but this enzyme has very little activity in cats.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', 2814, 'Tue, 26 Mar 2019 04:19:09 GMT'], [' and flattened ears indicates hostility.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', 2814, 'Tue, 26 Mar 2019 04:19:09 GMT']]
# [[' later identified as a domestic cat.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:13 GMT'], [' but this enzyme has very little activity in cats.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:13 GMT'], [' and flattened ears indicates hostility.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:13 GMT']]
# [[' later identified as a domestic cat.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:16 GMT'], [' but this enzyme has very little activity in cats.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:16 GMT'], [' and flattened ears indicates hostility.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:16 GMT']]
# [[' later identified as a domestic cat.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:19 GMT'], [' but this enzyme has very little activity in cats.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:19 GMT'], [' and flattened ears indicates hostility.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 2814, 'Tue, 26 Mar 2019 04:19:19 GMT']]
# [[' application error occurred on the server.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 0, ''], [' Application.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 0, ''], [' configuration file located in the root directory of the current web application.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Mothercatandkitten-malawi-2018.webm/220px-seek%3D2-Mothercatandkitten-malawi-2018.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Cat_skull.jpg/220px-Cat_skull.jpg', 0, '']]
# [[' you might not know about dogs and cats.', '', 'https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/news/2015/06_2015/fake_online_pharmacies/110x70_fake_online_pharmacies.jpg?resize=110px:*&output-quality=50', 'https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/video/caring_for_dog_with_food_allergies_video/650x350_caring_for_dog_with_food_allergies_video.jpg?resize=195px:*&output-quality=50', 220, '']]
# [[' charges applicable tax on all orders to states in which Petco has a physical location.', '', '/wcsstore/PetcoSAS/images/loading.gif', '/wcsstore/PetcoStore/img/brand-logo.png', 270, ''], [' cat toy order subtotal.', '', '/wcsstore/PetcoSAS/images/loading.gif', '/wcsstore/PetcoStore/img/brand-logo.png', 270, ''], [' petcoLocation.', '', '/wcsstore/PetcoSAS/images/loading.gif', '/wcsstore/PetcoStore/img/brand-logo.png', 270, '']]
# [[' charges applicable tax on all orders to states in which Petco has a physical location.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 283, ''], [' cat toy order subtotal.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 283, ''], [' petcoLocation.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 283, '']]
# [[' charges applicable tax on all orders to states in which Petco has a physical location.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 270, ''], [' cat toy order subtotal.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 270, ''], [' petcoLocation.', '', '/wcsstore/PetcoSAS/images/loading.gif', '//s7d1.scene7.com/is/image/PETCO/shopping-made-easy-020719-quick-reorder-icon-125w-125h?$transparent_unsized$&wid=120', 270, '']]
# [[' location.', '', '//s7d1.scene7.com/is/image/PETCO/rd-always-earn5back-051718-icon-36w-36h?$transparent_unsized$', 'https://s7d1.scene7.com/is/image/PETCO/bird-shop-by-pet-091117-thumbnail-175w-200h', 5, '']]
# [[' location.', '', '', '', 37, '']]
# [[' location.', '', '', '', 5, '']]
# [[' the Morningstar category is assigned based on the underlying securities in each portfolio.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, ''], [' billion.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, ''], [' million last year.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, '']]
# [[' the Morningstar category is assigned based on the underlying securities in each portfolio.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 29, ''], [' have no new notifications.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 29, ''], [' will send you notifications about latest breaking news.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 29, '']]
# [[' the Morningstar category is assigned based on the underlying securities in each portfolio.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, ''], [' billion.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, ''], [' million last year.', '', 'https://s.yimg.com/uu/api/res/1.2/0yNqmdptAhwu_sog4e83yQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/b9775f315e7b6c4ada6e36d0048a929a', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 50, '']]
# [[' communication in languages other than English.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 261, 'Tue, 26 Mar 2019 04:06:06 GMT'], [' The Bond novel received broadly positive reviews at the time of publication.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', 'https://s.yimg.com/uu/api/res/1.2/Wh4VKC44pBLDwqBIcBlfOQ--~B/Zmk9c3RyaW07aD0xMjM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/d96a4b926fd0538efed82da730ec5d2d', 261, 'Tue, 26 Mar 2019 04:06:06 GMT']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png', 91, 'Tue, 26 Mar 2019 04:21:09 GMT'], [' million visitors from all over the world each year.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png', 91, 'Tue, 26 Mar 2019 04:21:09 GMT']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 97, '']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 91, 'Tue, 26 Mar 2019 04:21:15 GMT'], [' million visitors from all over the world each year.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 91, 'Tue, 26 Mar 2019 04:21:15 GMT']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-', 91, 'Tue, 26 Mar 2019 04:21:24 GMT'], [' million visitors from all over the world each year.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-', 91, 'Tue, 26 Mar 2019 04:21:24 GMT']]
# [[' communication in languages other than English.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png', 261, 'Tue, 26 Mar 2019 04:06:06 GMT'], [' The Bond novel received broadly positive reviews at the time of publication.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35px-Wikisource-logo.svg.png', 261, 'Tue, 26 Mar 2019 04:06:06 GMT']]
# [[' a fearsome Bengal tiger.', '', '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png', 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/film-293970583._CB483525279_.png', 377, '']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '', 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/film-293970583._CB483525279_.png', 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/32x44/name-2138558783._CB470041625_.png', 91, 'Tue, 26 Mar 2019 04:21:37 GMT'], [' million visitors from all over the world each year.', '', 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/small/film-293970583._CB483525279_.png', 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/32x44/name-2138558783._CB470041625_.png', 91, 'Tue, 26 Mar 2019 04:21:37 GMT']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 97, '']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 91, 'Tue, 26 Mar 2019 04:21:45 GMT'], [' million visitors from all over the world each year.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/480x240_scale_and_crop/public/animals/cheetah-002.jpg?itok=iBiVKo1m&timestamp=1520537679', 91, 'Tue, 26 Mar 2019 04:21:45 GMT']]
# [[' We offer visitors a chat bot concierge that may not be compatible with your accessibility application.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-', 91, 'Tue, 26 Mar 2019 04:21:52 GMT'], [' million visitors from all over the world each year.', '/sites/all/themes/si_nzp/logo.svg', '', 'https://nationalzoo.si.edu/sites/default/files/styles/teaser-mobile/public/slideshow/natural_material_exploration.jpg?itok=wx8Vc4i-', 91, 'Tue, 26 Mar 2019 04:21:52 GMT']]
